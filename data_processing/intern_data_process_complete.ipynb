# %%
# importing necessary libraries

import numpy as np
import pandas as pd

# %%
# loading first csv file 

df1 = pd.read_csv('first_links.csv')
df1.sample(5)
# Out:
#       Unnamed: 0       source        location  \
# 4820        4820  internshala  work_from_home
# 2926        2926  internshala  work_from_home
# 2461        2461  internshala  work_from_home
# 7652        7652  internshala       bangalore
# 1114        1114  internshala  work_from_home
#
#                                                job_link
# 4820  https://internshala.com/internship/details/inf...
# 2926  https://internshala.com/internship/detail/oper...
# 2461  https://internshala.com/internship/details/med...
# 7652  https://internshala.com/internship/detail/busi...
# 1114  https://internshala.com/internship/details/hum...

# %%
# getting size of first extracted csv file
df1.shape
# Out:
# (8124, 4)

# %%
# loading second csv file to clean the data
df2 = pd.read_csv('second_data.csv')

# displaying the random job records
df2.sample(5)
# Out:
#       Unnamed: 0       source        location  \
# 378          378  internshala  work_from_home
# 7577        7577  internshala       bangalore
# 5450        5450  internshala  work_from_home
# 371          371  internshala  work_from_home
# 3866        3866  internshala  work_from_home
#
#                                                job_link  \
# 378   https://internshala.com/internship/detail/busi...
# 7577  https://internshala.com/internship/detail/comp...
# 5450  https://internshala.com/internship/detail/busi...
# 371   https://internshala.com/internship/detail/cate...
# 3866  https://internshala.com/internship/details/dig...
#
#                          job_title  \
# 378   Business Development (Sales)
# 7577               Computer Vision
# 5450  Business Development (Sales)
# 371            Category Management
# 3866             Digital Marketing
#
#                                         company_name  \
# 378   Freecharge Payments Technology Private Limited
# 7577      Perfios Software Solutions Private Limited
# 5450    UrbanClap Technologies India Private Limited
# 371                                        UrbanClap
# 3866                                  Times Internet
#
#                                              imp_fields  \
# 378   ['Starts\xa0immediatelyImmediately', '3 Months...
# 7577  ['Starts\xa0immediatelyImmediately', '6 Months...
# 5450  ['Starts\xa0immediatelyImmediately', '2 Months...
# 371   ['Starts\xa0immediatelyImmediately', '1 Month'...
# 3866  ['Starts\xa0immediatelyImmediately', '6 Months...
#
#                                    description_headings  \
# 378   ['About Freecharge Payments Technology Private...
# 7577  ['About Perfios Software Solutions Private Lim...
# 5450  ['About UrbanClap Technologies India Private L...
# 371   ['About UrbanClap', 'About the work from home ...
# 3866  ['About Times Internet', 'About the work from ...
#
#                                             description
# 378   About Freecharge Payments Technology Private L...
# 7577  About Perfios Software Solutions Private Limit...
# 5450  About UrbanClap Technologies India Private Lim...
# 371   About UrbanClap        \r\n\r\nhttps://www.urb...
# 3866  About Times Internet        \r\n\r\nhttp://tim...

# %%
# getting size of csv file which returns the tuple of x records and y columns
df2.shape
# Out:
# (8115, 9)

# %%
'''
taking five empty list then 
performing the data cleaning by removing square braces and removing starting quotes
then spliting the data based on the delimiter ','.

**note: while scraping the data I used the list to extract the details. Instead we can use string to store values but we need 
to give a unique delimiter for future cleaning while extracting.

'''

start = []
duration = []
stipend = []
last_date = []
job_mode = []
for a in df2.imp_fields:
    a = a.replace(']','')
    a = a.replace('[','')
    a = a.replace("'",'')
    a = a.replace('"','')
    start.append(a.split(',')[0].strip())
    duration.append(a.split(',')[1].strip())
    stipend.append(a.split(',')[2].strip())
    last_date.append(a.split(',')[3].strip())
    if(len(a.split(','))==5):
        # for locations of jobs/internships there may not be presence of jobs. At that time it throws error.
        job_mode.append(a.split(',')[4].strip())
    else:
        job_mode.append(None)

# %%
# adding those extracted lists to the dataframe with respective column names

df2['start_date'] = start
df2['duration'] = duration
df2['stipend'] = stipend
df2['last_date'] = last_date
df2['job_mode'] = job_mode

# %%
# printing the randoms records from the dataframe to check new columns
df2.sample(5)
# Out:
#       Unnamed: 0       source        location  \
# 5503        5503  internshala  work_from_home
# 6239        6239  internshala  work_from_home
# 72            72  internshala  work_from_home
# 7783        7783  internshala       bangalore
# 757          757  internshala  work_from_home
#
#                                                job_link  \
# 5503  https://internshala.com/internship/details/dev...
# 6239  https://internshala.com/internship/detail/oper...
# 72    https://internshala.com/internship/details/soc...
# 7783  https://internshala.com/internship/detail/inte...
# 757   https://internshala.com/internship/details/con...
#
#                    job_title           company_name  \
# 5503     Development Support     Child Rights & You
# 6239              Operations              UrbanClap
# 72    Social Media Marketing       HCL Technologies
# 7783         Interior Design  Mokham Design & Build
# 757          Content Writing          Motilal Oswal
#
#                                              imp_fields  \
# 5503  ['Starts\xa0immediatelyImmediately', '2 Months...
# 6239  ['Starts\xa0immediatelyImmediately', '2 Months...
# 72    ['Starts\xa0immediatelyImmediately', '1 Month'...
# 7783  ['Starts\xa0immediatelyImmediately', '6 Months...
# 757   ['Starts\xa0immediatelyImmediately', '4 Months...
#
#                                    description_headings  \
# 5503  ['About Child Rights & You', 'About the work f...
# 6239  ['About UrbanClap', 'About the work from home ...
# 72    ['About HCL Technologies', 'About the work fro...
# 7783  ['About Mokham Design & Build', 'About the int...
# 757   ['About Motilal Oswal', 'About the work from h...
#
#                                             description  \
# 5503  About Child Rights & You        \r\n\r\nhttps:...
# 6239  About UrbanClap        \r\n\r\nhttps://www.urb...
# 72    About HCL Technologies        \r\n\r\nhttps://...
# 7783  About Mokham Design & Build        \r\n\r\nhtt...
# 757   About Motilal Oswal        \r\n\r\nhttp://www....
#
#                             start_date  duration       stipend  last_date  \
# 5503  Starts\xa0immediatelyImmediately  2 Months        Unpaid  17 Jun 20
# 6239  Starts\xa0immediatelyImmediately  2 Months  10000 /month  26 Jun 20
# 72    Starts\xa0immediatelyImmediately   1 Month   3500 /month   2 Jun 20
# 7783  Starts\xa0immediatelyImmediately  6 Months   4000 /month  29 Jun 20
# 757   Starts\xa0immediatelyImmediately  4 Months   2000 /month  15 Jun 20
#
#                job_mode
# 5503  Part time allowed
# 6239  Part time allowed
# 72    Part time allowed
# 7783               None
# 757   Part time allowed

# %%
# operation to check unique values and number of times it present
print(df2.start_date.value_counts())
# Out:
# Starts\xa0immediatelyImmediately    8099
# 1 Jul - 10 Jul 20                     16
# Name: start_date, dtype: int64

# %%
# instead of 'Starts\xa0immediatelyImmediately' giving simiply immediately    
for i in range(len(df2['start_date'])):
    if( df2['start_date'][i] == 'Starts\\xa0immediatelyImmediately'):
        df2['start_date'][i] = 'immediately'
df2.sample(5)
# Out:
#       Unnamed: 0       source        location  \
# 3827        3827  internshala  work_from_home
# 7416        7416  internshala       bangalore
# 6651        6651  internshala  work_from_home
# 5368        5368  internshala  work_from_home
# 7593        7593  internshala       bangalore
#
#                                                job_link  \
# 3827  https://internshala.com/internship/details/hum...
# 7416  https://internshala.com/internship/detail/law-...
# 6651  https://internshala.com/internship/detail/busi...
# 5368  https://internshala.com/internship/detail/ui-u...
# 7593  https://internshala.com/internship/detail/cont...
#
#                           job_title  \
# 3827           Human Resources (HR)
# 7416                     Law/ Legal
# 6651   Business Development (Sales)
# 5368                   UI/UX Design
# 7593  Content Development (English)
#
#                                         company_name  \
# 3827                        HCL Technologies Limited
# 7416                            Dr Gubbi S Subba Rao
# 6651  Freecharge Payments Technology Private Limited
# 5368                             Kotak Mahindra Bank
# 7593                                       Unacademy
#
#                                              imp_fields  \
# 3827  ['Starts\xa0immediatelyImmediately', '3 Months...
# 7416  ['Starts\xa0immediatelyImmediately', '1 Month'...
# 6651  ['Starts\xa0immediatelyImmediately', '3 Months...
# 5368  ['Starts\xa0immediatelyImmediately', '6 Months...
# 7593  ['Starts\xa0immediatelyImmediately', '2 Months...
#
#                                    description_headings  \
# 3827  ['About HCL Technologies Limited', 'About the ...
# 7416  ['About Dr Gubbi S Subba Rao', 'About part tim...
# 6651  ['About Freecharge Payments Technology Private...
# 5368  ['About Kotak Mahindra Bank', 'About the work ...
# 7593  ['About Unacademy', 'About the internship', 'S...
#
#                                             description   start_date  \
# 3827  About HCL Technologies Limited        \r\n\r\n...  immediately
# 7416  About Dr Gubbi S Subba Rao        \r\n\r\nhttp...  immediately
# 6651  About Freecharge Payments Technology Private L...  immediately
# 5368  About Kotak Mahindra Bank        \r\n\r\nhttps...  immediately
# 7593  About Unacademy        \r\n\r\nhttps://unacade...  immediately
#
#       duration             stipend  last_date           job_mode
# 3827  3 Months    3500-6000 /month  17 Jun 20  Part time allowed
# 7416   1 Month         5000 /month  29 Jun 20  Part time allowed
# 6651  3 Months        10000 /month  18 Jun 20  Part time allowed
# 5368  6 Months        15000 /month  25 Jun 20  Part time allowed
# 7593  2 Months  10000-12000 /month  16 Jun 20               None

# %%
# cleaning the text in headers columns and adding to a list

headings = []
for a in df2.description_headings:
    a = a.replace(']','')
    a = a.replace('[','')
    a = a.replace("'",'')
    headings.append(a.split(','))

# %%
# replacing the cleaned text in heading
df2.description_headings = headings

# %%
df2.sample(5)
# Out:
#       Unnamed: 0       source        location  \
# 990          990  internshala  work_from_home
# 6243        6243  internshala  work_from_home
# 13            13  internshala  work_from_home
# 6803        6803  internshala  work_from_home
# 442          442  internshala  work_from_home
#
#                                                job_link  \
# 990   https://internshala.com/internship/details/net...
# 6243  https://internshala.com/internship/detail/busi...
# 13    https://internshala.com/internship/detail/busi...
# 6803  https://internshala.com/internship/detail/onli...
# 442   https://internshala.com/internship/detail/ente...
#
#                                job_title  \
# 990   Networking & System Administration
# 6243        Business Development (Sales)
# 13          Business Development (Sales)
# 6803                Online Crowd Funding
# 442                  Enterprise Accounts
#
#                                       company_name  \
# 990             The Energy And Resources Institute
# 6243  UrbanClap Technologies India Private Limited
# 13              Toppr Technologies Private Limited
# 6803                    CRY - Child Rights and You
# 442                                          Dunzo
#
#                                              imp_fields  \
# 990   ['Starts\xa0immediatelyImmediately', '6 Months...
# 6243  ['Starts\xa0immediatelyImmediately', '2 Months...
# 13    ['Starts\xa0immediatelyImmediately', '3 Months...
# 6803  ['Starts\xa0immediatelyImmediately', '4 Weeks'...
# 442   ['Starts\xa0immediatelyImmediately', '6 Months...
#
#                                    description_headings  \
# 990   [About The Energy And Resources Institute,  Ab...
# 6243  [About UrbanClap Technologies India Private Li...
# 13    [About Toppr Technologies Private Limited,  Ab...
# 6803  [About CRY - Child Rights and You,  About the ...
# 442   [About Dunzo,  About the work from home job/in...
#
#                                             description   start_date  \
# 990   About The Energy And Resources Institute      ...  immediately
# 6243  About UrbanClap Technologies India Private Lim...  immediately
# 13    About Toppr Technologies Private Limited      ...  immediately
# 6803  About CRY - Child Rights and You        \r\n\r...  immediately
# 442   About Dunzo        \r\n\r\nhttp://dunzo.in/ \r...  immediately
#
#       duration                    stipend  last_date           job_mode
# 990   6 Months                5000 /month  16 Jun 20  Part time allowed
# 6243  2 Months                8000 /month  25 Jun 20  Part time allowed
# 13    3 Months  8000 /month +  Incentives  23 Jun 20  Part time allowed
# 6803   4 Weeks                     Unpaid  23 Jun 20  Part time allowed
# 442   6 Months               10000 /month  29 Jun 20  Part time allowed

# %%
# droping the unwanted columns in the dataframe
df3 = df2.drop(['Unnamed: 0','imp_fields'],axis = 'columns')

# %%
df3.head(5)
# Out:
#         source        location  \
# 0  internshala  work_from_home
# 1  internshala  work_from_home
# 2  internshala  work_from_home
# 3  internshala  work_from_home
# 4  internshala  work_from_home
#
#                                             job_link  \
# 0  https://internshala.com/internship/detail/mobi...
# 1  https://internshala.com/internship/detail/cont...
# 2  https://internshala.com/internship/detail/ente...
# 3  https://internshala.com/internship/detail/busi...
# 4  https://internshala.com/internship/detail/grap...
#
#                       job_title         company_name  \
# 0        Mobile App Development  NCFlexe, IIT Kanpur
# 1               Content Writing              Nearbuy
# 2           Enterprise Accounts                Dunzo
# 3  Business Development (Sales)        Urban Company
# 4                Graphic Design          Sportskeeda
#
#                                 description_headings  \
# 0  [About NCFlexe,  IIT Kanpur,  About the work f...
# 1  [About Nearbuy,  About the work from home job/...
# 2  [About Dunzo,  About the work from home job/in...
# 3  [About Urban Company,  About the work from hom...
# 4  [About Sportskeeda,  About the work from home ...
#
#                                          description   start_date  duration  \
# 0  About NCFlexe, IIT Kanpur        \r\n\r\n    N...  immediately  2 Months
# 1  About Nearbuy        \r\n\r\nhttps://www.nearb...  immediately  6 Months
# 2  About Dunzo        \r\n\r\nhttp://dunzo.in/ \r...  immediately  6 Months
# 3  About Urban Company        \r\n\r\nhttp://urba...  immediately   1 Month
# 4  About Sportskeeda        \r\n\r\nhttps://www.s...  immediately  3 Months
#
#               stipend  last_date           job_mode
# 0         5000 /month  29 Jun 20  Part time allowed
# 1        10000 /month  29 Jun 20  Part time allowed
# 2        10000 /month  29 Jun 20  Part time allowed
# 3        10000 /month  27 Jun 20  Part time allowed
# 4  12000-15000 /month  26 Jun 20  Part time allowed

# %%
# checking the headers in the dataframe
df3.description_headings[0]
# Out:
# ['About NCFlexe',
#  ' IIT Kanpur',
#  ' About the work from home job/internship',
#  ' Skill(s) required',
#  ' Who can apply',
#  ' Perks',
#  ' Number of openings']

# %%
# displaying the text and comparing manually based on the headers

print(df3.description[0])
# Out:
# About NCFlexe, IIT Kanpur
#
#     National Centre for Flexible Electronics (NCFlexe) was established in 2014 through a grant from the Department of Electronics and Information Technology (DeitY) under ESDM scheme of Electronics Policy, 2012 of Government of India and support from IIT Kanpur. This center functions as a nodal point in India to bring academia, industry and public research organizations under one umbrella for research and development of large area flexible electronics. The center simultaneously supports in research for the academia and develops products with (and also for) the industry.About the work from home job/internship
#
#     Selected intern's day-to-day responsibilities include:
#
# 1. Develop the UI for the Android app, interact with the graphics designer to lead a good user experience
# 2. Understand image processing and deep learning constraints and implement them at the interface for real-time feedback
# 3. Write production level code in Java
# 4. Work on data structure, OS, and database Skill(s) required
#
# Java
# Python
# Data Structures
#
#
# Learn these skills on Internshala Trainings
#
#
# Learn Java
#
#
# Learn Python
#
#
#
# Who can apply
#
# Only those candidates can apply who:
# 1. are available for the work from home job/internship
# 2. can start the work from home job/internship between 1st Jun'20 and 6th Jul'20
# 3. are available for duration of 2 months
# 4. have relevant skills and interests
#
#
# Perks
#
# Certificate
#  Letter of recommendation
#
# Number of openings
#
#         1
#
#
#
#
#                         Apply now

# %%
# attempting on single job description to extract skills 
start_pos = df3.description[0].find('Skill(s) required')
end_pos =df3.description[0].find('Who can apply')
print(df3.description[0][start_pos+17:end_pos].strip())
# Out:
# Java
# Python
# Data Structures
#
#
# Learn these skills on Internshala Trainings
#
#
# Learn Java
#
#
# Learn Python

# %%
def remodify(text):
    '''
    A function to extract the skills and not the duplicated skills.
    '''
    a = ''.join([i if((ord(i)>64 and ord(i)<91 ) or (ord(i) >96 and ord(i) <123)) else ' ' for i in text])
    pos = a.find('Learn these skills')
    if(pos>0):
        return(a[:pos].strip())
    else:
        return(a.strip())

# %%
# processing the actual cleaning from description.

skills = []
for index, text in enumerate(df3.description_headings):
    for i in text:
        if(i==' Skill(s) required'):
            start_pos = df3.description[index].find('Skill(s) required')
            end_pos =df3.description[index].find('Who can apply')
            skills.append(remodify(df3.description[index][start_pos+17:end_pos].strip()))
            #print(df3.description[index][start_pos+17:end_pos].strip())
            break
    else:
        #print(None)
        skills.append(None)

# %%
# adding the skill set to the dataframe
df3['skills'] = skills

# %%
df3.head(5)
# Out:
#         source        location  \
# 0  internshala  work_from_home
# 1  internshala  work_from_home
# 2  internshala  work_from_home
# 3  internshala  work_from_home
# 4  internshala  work_from_home
#
#                                             job_link  \
# 0  https://internshala.com/internship/detail/mobi...
# 1  https://internshala.com/internship/detail/cont...
# 2  https://internshala.com/internship/detail/ente...
# 3  https://internshala.com/internship/detail/busi...
# 4  https://internshala.com/internship/detail/grap...
#
#                       job_title         company_name  \
# 0        Mobile App Development  NCFlexe, IIT Kanpur
# 1               Content Writing              Nearbuy
# 2           Enterprise Accounts                Dunzo
# 3  Business Development (Sales)        Urban Company
# 4                Graphic Design          Sportskeeda
#
#                                 description_headings  \
# 0  [About NCFlexe,  IIT Kanpur,  About the work f...
# 1  [About Nearbuy,  About the work from home job/...
# 2  [About Dunzo,  About the work from home job/in...
# 3  [About Urban Company,  About the work from hom...
# 4  [About Sportskeeda,  About the work from home ...
#
#                                          description   start_date  duration  \
# 0  About NCFlexe, IIT Kanpur        \r\n\r\n    N...  immediately  2 Months
# 1  About Nearbuy        \r\n\r\nhttps://www.nearb...  immediately  6 Months
# 2  About Dunzo        \r\n\r\nhttp://dunzo.in/ \r...  immediately  6 Months
# 3  About Urban Company        \r\n\r\nhttp://urba...  immediately   1 Month
# 4  About Sportskeeda        \r\n\r\nhttps://www.s...  immediately  3 Months
#
#               stipend  last_date           job_mode  \
# 0         5000 /month  29 Jun 20  Part time allowed
# 1        10000 /month  29 Jun 20  Part time allowed
# 2        10000 /month  29 Jun 20  Part time allowed
# 3        10000 /month  27 Jun 20  Part time allowed
# 4  12000-15000 /month  26 Jun 20  Part time allowed
#
#                                               skills
# 0                      Java  Python  Data Structures
# 1                              Blogging  Copywriting
# 2                                          MS Office
# 3                                           MS Excel
# 4  Adobe Photoshop  Adobe Illustrator  Video Editing

# %%
# finding the unique job titles and its number of occurances
df3.job_title.value_counts()
# Out:
# Business Development (Sales)                      1788
# Content Writing                                    775
# Human Resources (HR)                               565
# Operations                                         417
# Graphic Design                                     399
# Web Development                                    302
# Digital Marketing                                  214
# Social Media Marketing                             208
# Mobile App Development                             187
# Networking & System Administration                 181
# Content Development                                181
# Video Editing                                      181
# UI/UX Design                                       181
# Software Testing/Quality Assurance                 181
# Media & Communication                              181
# Online Crowd Funding                               181
# Category Management                                181
# Stock Market Research                              181
# Information Technology                             181
# Resource Generation                                181
# Data Entry (Typing)                                181
# Volunteering                                       181
# Development Support                                181
# Product Management                                 180
# Enterprise Accounts                                179
# Marketing                                           44
# Finance                                             32
# Software Testing                                    16
# Interior Design                                     16
# Computer Vision & Machine Learning                  16
# Law/ Legal                                          16
# Product Analysis                                    16
# Hindi Video Making/Editing                          16
# Automotive Clay Modelling                           16
# Computer Vision                                     16
# Circuit & PCB Designing                             16
# Research                                            16
# .NET Development                                    16
# Content Development (English)                       16
# Embedded DSP Development                            16
# Video Making/Editing                                16
# Flutter Development                                  6
# Drone Building                                       6
# E-Learning Development                               6
# COVID-19 Response Campaign And Fundraising           6
# Agriculture & Food Engineering                       6
# Administration                                       6
# Culinary Operations (Chef)                           6
# PHP Development (CMS)                                6
# Search Engine Optimization (SEO)                     6
# PHP Development                                      6
# Electronics Engineering (Arduino & 3D Printer)       6
# Seed Production                                      1
# Name: job_title, dtype: int64

# %%
# sample checking of unique job titles 
df3.job_title.unique()
# Out:
# array(['Mobile App Development', 'Content Writing', 'Enterprise Accounts',
#        'Business Development (Sales)', 'Graphic Design', 'Operations',
#        'UI/UX Design', 'Category Management', 'Online Crowd Funding',
#        'Web Development', 'Video Editing', 'Information Technology',
#        'Media & Communication', 'Volunteering', 'Development Support',
#        'Resource Generation', 'Content Development', 'Digital Marketing',
#        'Human Resources (HR)', 'Networking & System Administration',
#        'Software Testing/Quality Assurance', 'Social Media Marketing',
#        'Data Entry (Typing)', 'Stock Market Research',
#        'Product Management', 'Research', 'Content Development (English)',
#        'Circuit & PCB Designing', 'Hindi Video Making/Editing',
#        'Video Making/Editing', 'Product Analysis',
#        'Embedded DSP Development', 'Marketing',
#        'Computer Vision & Machine Learning', 'Finance',
#        'Automotive Clay Modelling', 'Law/ Legal', 'Computer Vision',
#        'Interior Design', '.NET Development', 'Software Testing',
#        'COVID-19 Response Campaign And Fundraising',
#        'Electronics Engineering (Arduino & 3D Printer)', 'Drone Building',
#        'Agriculture & Food Engineering', 'E-Learning Development',
#        'PHP Development (CMS)', 'Administration',
#        'Search Engine Optimization (SEO)', 'Flutter Development',
#        'PHP Development', 'Culinary Operations (Chef)', 'Seed Production'],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
# importing the matplotlib for visualization

# %%
# ploting the bar graph based on its occurances
df3.job_title.value_counts().plot(kind='barh', figsize=(30,26))
plt.show()

# %% [markdown]
# ### Points extracted
# 1. Business development which related to sales is the trending one it means it occured many times
# 2. Seed Production is the least occurred job

# %%
# extracting the no. of openings based on manual pattern

no_openings = []
for index, text in enumerate(df3.description_headings):
    for i in text:
        if(i==' Number of openings'):
            start_pos = df3.description[index].find('Number of openings')
            end_pos =df3.description[index].find('Apply now')
            no_openings.append(df3.description[index][start_pos+19:end_pos].strip())
            #print(df3.description[index][start_pos+19:end_pos].strip())
            break
    else:
        #print(None)
        no_openings.append(None)

# %%
# appending the number of openings to the dataframe
df3['no_of_openings'] = no_openings

# %%
df3.sample(15)
# Out:
#            source        location  \
# 5015  internshala  work_from_home
# 4499  internshala  work_from_home
# 910   internshala  work_from_home
# 5123  internshala  work_from_home
# 5726  internshala  work_from_home
# 4665  internshala  work_from_home
# 4063  internshala  work_from_home
# 2327  internshala  work_from_home
# 2787  internshala  work_from_home
# 2733  internshala  work_from_home
# 4506  internshala  work_from_home
# 6039  internshala  work_from_home
# 2062  internshala  work_from_home
# 4386  internshala  work_from_home
# 6647  internshala  work_from_home
#
#                                                job_link  \
# 5015  https://internshala.com/internship/detail/web-...
# 4499  https://internshala.com/internship/details/bus...
# 910   https://internshala.com/internship/details/net...
# 5123  https://internshala.com/internship/detail/busi...
# 5726  https://internshala.com/internship/detail/oper...
# 4665  https://internshala.com/internship/details/con...
# 4063  https://internshala.com/internship/details/dev...
# 2327  https://internshala.com/internship/detail/cont...
# 2787  https://internshala.com/internship/details/hum...
# 2733  https://internshala.com/internship/detail/busi...
# 4506  https://internshala.com/internship/details/dig...
# 6039  https://internshala.com/internship/detail/cont...
# 2062  https://internshala.com/internship/details/vol...
# 4386  https://internshala.com/internship/details/dig...
# 6647  https://internshala.com/internship/detail/busi...
#
#                                job_title  \
# 5015                     Web Development
# 4499        Business Development (Sales)
# 910   Networking & System Administration
# 5123        Business Development (Sales)
# 5726                          Operations
# 4665                 Content Development
# 4063                 Development Support
# 2327                     Content Writing
# 2787                Human Resources (HR)
# 2733        Business Development (Sales)
# 4506                   Digital Marketing
# 6039                     Content Writing
# 2062                        Volunteering
# 4386                   Digital Marketing
# 6647        Business Development (Sales)
#
#                                       company_name  \
# 5015                                 IIT Hyderabad
# 4499  UrbanClap Technologies India Private Limited
# 910             The Energy And Resources Institute
# 5123                                 Urban Company
# 5726                                     UrbanClap
# 4665                                   Sportskeeda
# 4063                            Child Rights & You
# 2327         Zee Entertainment Enterprises Limited
# 2787                      HCL Technologies Limited
# 2733            Toppr Technologies Private Limited
# 4506                                Times Internet
# 6039                                       Nearbuy
# 2062                            Child Rights & You
# 4386                                Times Internet
# 6647            Toppr Technologies Private Limited
#
#                                    description_headings  \
# 5015  [About IIT Hyderabad,  About the work from hom...
# 4499  [About UrbanClap Technologies India Private Li...
# 910   [About The Energy And Resources Institute,  Ab...
# 5123  [About Urban Company,  About the work from hom...
# 5726  [About UrbanClap,  About the work from home jo...
# 4665  [About Sportskeeda,  About the work from home ...
# 4063  [About Child Rights & You,  About the work fro...
# 2327  [About Zee Entertainment Enterprises Limited, ...
# 2787  [About HCL Technologies Limited,  About the wo...
# 2733  [About Toppr Technologies Private Limited,  Ab...
# 4506  [About Times Internet,  About the work from ho...
# 6039  [About Nearbuy,  About the work from home job/...
# 2062  [About Child Rights & You,  About the work fro...
# 4386  [About Times Internet,  About the work from ho...
# 6647  [About Toppr Technologies Private Limited,  Ab...
#
#                                             description   start_date  \
# 5015  About IIT Hyderabad        \r\n\r\nhttps://www...  immediately
# 4499  About UrbanClap Technologies India Private Lim...  immediately
# 910   About The Energy And Resources Institute      ...  immediately
# 5123  About Urban Company        \r\n\r\nhttp://urba...  immediately
# 5726  About UrbanClap        \r\n\r\nhttps://www.urb...  immediately
# 4665  About Sportskeeda        \r\n\r\nhttps://www.s...  immediately
# 4063  About Child Rights & You        \r\n\r\nhttps:...  immediately
# 2327  About Zee Entertainment Enterprises Limited   ...  immediately
# 2787  About HCL Technologies Limited        \r\n\r\n...  immediately
# 2733  About Toppr Technologies Private Limited      ...  immediately
# 4506  About Times Internet        \r\n\r\nhttp://tim...  immediately
# 6039  About Nearbuy        \r\n\r\nhttps://www.nearb...  immediately
# 2062  About Child Rights & You        \r\n\r\nhttps:...  immediately
# 4386  About Times Internet        \r\n\r\nhttp://tim...  immediately
# 6647  About Toppr Technologies Private Limited      ...  immediately
#
#        duration                    stipend  last_date           job_mode  \
# 5015    1 Month                     Unpaid  19 Jun 20  Part time allowed
# 4499   2 Months           5000-8000 /month  18 Jun 20  Part time allowed
# 910    6 Months                5000 /month  16 Jun 20  Part time allowed
# 5123    1 Month               10000 /month  27 Jun 20  Part time allowed
# 5726   2 Months               10000 /month  26 Jun 20  Part time allowed
# 4665   3 Months  7000 /month +  Incentives  17 Jun 20  Part time allowed
# 4063   2 Months                     Unpaid  17 Jun 20  Part time allowed
# 2327  12 Months           3000-5000 /month  25 Jun 20  Part time allowed
# 2787   3 Months           3500-6000 /month  17 Jun 20  Part time allowed
# 2733   3 Months  8000 /month +  Incentives  23 Jun 20  Part time allowed
# 4506   6 Months                1000 /month  17 Jun 20  Part time allowed
# 6039   6 Months               10000 /month  29 Jun 20  Part time allowed
# 2062   2 Months                     Unpaid  17 Jun 20  Part time allowed
# 4386   6 Months                1000 /month  17 Jun 20  Part time allowed
# 6647   6 Months  2000 /month +  Incentives  20 Jun 20  Part time allowed
#
#                                                  skills no_of_openings
# 5015  PHP  HTML  CSS  Adobe Dreamweaver  Search Engi...              2
# 4499  English Proficiency  Spoken   Hindi Proficienc...              3
# 910                                                None              2
# 5123                                           MS Excel              2
# 5726                                               None             20
# 4665                       English Proficiency  Written              3
# 4063                                               None            100
# 2327                                               None             20
# 2787  MS Office  MS Excel  English Proficiency  Spok...             15
# 2733                                         Salesforce              4
# 4506                                               None              2
# 6039                              Blogging  Copywriting              1
# 2062                                               None            100
# 4386                                               None              2
# 6647                                               None             20

# %%
# extracting months of internship from the duration column
months_number = []
for i in df3.duration:
    months_number.append(int(i.split()[0]))
df3['months_duration'] = months_number

# %%
df3.sample(10)
# Out:
#            source        location  \
# 7846  internshala       bangalore
# 1185  internshala  work_from_home
# 3525  internshala  work_from_home
# 6988  internshala  work_from_home
# 1331  internshala  work_from_home
# 5305  internshala  work_from_home
# 5709  internshala  work_from_home
# 5851  internshala  work_from_home
# 6903  internshala  work_from_home
# 187   internshala  work_from_home
#
#                                                job_link  \
# 7846  https://internshala.com/internship/detail/oper...
# 1185  https://internshala.com/internship/details/con...
# 3525  https://internshala.com/internship/details/bus...
# 6988  https://internshala.com/internship/details/con...
# 1331  https://internshala.com/internship/detail/cate...
# 5305  https://internshala.com/internship/details/con...
# 5709  https://internshala.com/internship/details/hum...
# 5851  https://internshala.com/internship/detail/cate...
# 6903  https://internshala.com/internship/details/soc...
# 187   https://internshala.com/internship/details/hum...
#
#                          job_title                      company_name  \
# 7846                    Operations                         Housewise
# 1185           Content Development                       Sportskeeda
# 3525  Business Development (Sales)          LBB -  Little Black Book
# 6988               Content Writing                     Motilal Oswal
# 1331           Category Management                         UrbanClap
# 5305           Content Development                       Sportskeeda
# 5709          Human Resources (HR)  Dr. Reddy's Laboratories Limited
# 5851           Category Management                         UrbanClap
# 6903        Social Media Marketing                  HCL Technologies
# 187           Human Resources (HR)          HCL Technologies Limited
#
#                                    description_headings  \
# 7846  [About Housewise,  About part time job/interns...
# 1185  [About Sportskeeda,  About the work from home ...
# 3525  [About LBB -  Little Black Book,  About the wo...
# 6988  [About Motilal Oswal,  About the work from hom...
# 1331  [About UrbanClap,  About the work from home jo...
# 5305  [About Sportskeeda,  About the work from home ...
# 5709  ["About Dr. Reddys Laboratories Limited",  Abo...
# 5851  [About UrbanClap,  About the work from home jo...
# 6903  [About HCL Technologies,  About the work from ...
# 187   [About HCL Technologies Limited,  About the wo...
#
#                                             description   start_date  \
# 7846  About Housewise        \r\n\r\nhttp://www.hous...  immediately
# 1185  About Sportskeeda        \r\n\r\nhttps://www.s...  immediately
# 3525  About LBB -  Little Black Book        \r\n\r\n...  immediately
# 6988  About Motilal Oswal        \r\n\r\nhttp://www....  immediately
# 1331  About UrbanClap        \r\n\r\nhttps://www.urb...  immediately
# 5305  About Sportskeeda        \r\n\r\nhttps://www.s...  immediately
# 5709  About Dr. Reddy's Laboratories Limited        ...  immediately
# 5851  About UrbanClap        \r\n\r\nhttps://www.urb...  immediately
# 6903  About HCL Technologies        \r\n\r\nhttps://...  immediately
# 187   About HCL Technologies Limited        \r\n\r\n...  immediately
#
#       duration                    stipend  last_date           job_mode  \
# 7846  3 Months          7000-10000 /month  29 Jun 20  Part time allowed
# 1185  3 Months  7000 /month +  Incentives  17 Jun 20  Part time allowed
# 3525  3 Months           3500-5000 /month  26 Jun 20  Part time allowed
# 6988  4 Months                2000 /month  15 Jun 20  Part time allowed
# 1331   1 Month                8000 /month  24 Jun 20  Part time allowed
# 5305  3 Months  7000 /month +  Incentives  17 Jun 20  Part time allowed
# 5709  2 Months                1000 /month  16 Jun 20  Part time allowed
# 5851   1 Month                8000 /month  24 Jun 20  Part time allowed
# 6903   1 Month                3500 /month   2 Jun 20  Part time allowed
# 187   3 Months           3500-6000 /month  17 Jun 20  Part time allowed
#
#                                                  skills  \
# 7846                                               None
# 1185                       English Proficiency  Written
# 3525  MS Office  Adobe Photoshop  Magento  English P...
# 6988                                               None
# 1331                                               None
# 5305                       English Proficiency  Written
# 5709                                               None
# 5851                                               None
# 6903
# 187   MS Office  MS Excel  English Proficiency  Spok...
#
#                                          no_of_openings  months_duration
# 7846                                                  2                3
# 1185                                                  3                3
# 3525                                                  4                3
# 6988                                                 10                4
# 1331                                                  3                1
# 5305                                                  3                3
# 5709                                                  1                2
# 5851                                                  3                1
# 6903  20    \r\n\r\n\r\n\r\n                    Clos...                1
# 187                                                  15                3

# %%
# visualizing the pie about the number of job posting and its duration
plt.pie(df3.months_duration.value_counts(),labels=df3.months_duration.value_counts().index)
plt.title("months duration summary")
plt.show()

# %% [markdown]
# ### Points extracted:
# 1. mostly companies looking for 2 and 3 months duration internships
# 2. companies are not going to take interns for period of 5,7,8,9,10,11 months
# 3. by manual understanding of data that the internships of 12 months are unpaid jobs

# %%
df3.sample(10)
# Out:
#            source        location  \
# 2201  internshala  work_from_home
# 4425  internshala  work_from_home
# 1883  internshala  work_from_home
# 6966  internshala  work_from_home
# 3212  internshala  work_from_home
# 5130  internshala  work_from_home
# 6934  internshala  work_from_home
# 935   internshala  work_from_home
# 3159  internshala  work_from_home
# 1165  internshala  work_from_home
#
#                                                job_link  \
# 2201  https://internshala.com/internship/detail/cont...
# 4425  https://internshala.com/internship/details/con...
# 1883  https://internshala.com/internship/detail/busi...
# 6966  https://internshala.com/internship/detail/web-...
# 3212  https://internshala.com/internship/detail/onli...
# 5130  https://internshala.com/internship/detail/busi...
# 6934  https://internshala.com/internship/details/dev...
# 935   https://internshala.com/internship/detail/web-...
# 3159  https://internshala.com/internship/details/pro...
# 1165  https://internshala.com/internship/details/bus...
#
#                          job_title  \
# 2201               Content Writing
# 4425           Content Development
# 1883  Business Development (Sales)
# 6966               Web Development
# 3212          Online Crowd Funding
# 5130  Business Development (Sales)
# 6934           Development Support
# 935                Web Development
# 3159            Product Management
# 1165  Business Development (Sales)
#
#                                       company_name  \
# 2201                                       Nearbuy
# 4425                                   Sportskeeda
# 1883                                 Urban Company
# 6966                                 IIT Hyderabad
# 3212                    CRY - Child Rights and You
# 5130  UrbanClap Technologies India Private Limited
# 6934                            Child Rights & You
# 935                                  IIT Hyderabad
# 3159                  Forbes Center For Excellence
# 1165                      LBB -  Little Black Book
#
#                                    description_headings  \
# 2201  [About Nearbuy,  About the work from home job/...
# 4425  [About Sportskeeda,  About the work from home ...
# 1883  [About Urban Company,  About the work from hom...
# 6966  [About IIT Hyderabad,  About the work from hom...
# 3212  [About CRY - Child Rights and You,  About the ...
# 5130  [About UrbanClap Technologies India Private Li...
# 6934  [About Child Rights & You,  About the work fro...
# 935   [About IIT Hyderabad,  About the work from hom...
# 3159  [About Forbes Center For Excellence,  About th...
# 1165  [About LBB -  Little Black Book,  About the wo...
#
#                                             description   start_date  \
# 2201  About Nearbuy        \r\n\r\nhttps://www.nearb...  immediately
# 4425  About Sportskeeda        \r\n\r\nhttps://www.s...  immediately
# 1883  About Urban Company        \r\n\r\nhttp://urba...  immediately
# 6966  About IIT Hyderabad        \r\n\r\nhttps://www...  immediately
# 3212  About CRY - Child Rights and You        \r\n\r...  immediately
# 5130  About UrbanClap Technologies India Private Lim...  immediately
# 6934  About Child Rights & You        \r\n\r\nhttps:...  immediately
# 935   About IIT Hyderabad        \r\n\r\nhttps://www...  immediately
# 3159  About Forbes Center For Excellence        \r\n...  immediately
# 1165  About LBB -  Little Black Book        \r\n\r\n...  immediately
#
#       duration                    stipend  last_date           job_mode  \
# 2201  6 Months               10000 /month  29 Jun 20  Part time allowed
# 4425  3 Months  7000 /month +  Incentives  17 Jun 20  Part time allowed
# 1883   1 Month               10000 /month  27 Jun 20  Part time allowed
# 6966   1 Month                     Unpaid  19 Jun 20  Part time allowed
# 3212   4 Weeks                     Unpaid  23 Jun 20  Part time allowed
# 5130  2 Months                8000 /month  25 Jun 20  Part time allowed
# 6934  2 Months                     Unpaid  17 Jun 20  Part time allowed
# 935    1 Month                     Unpaid  19 Jun 20  Part time allowed
# 3159  3 Months               10000 /month  12 Jun 20  Part time allowed
# 1165  3 Months           3500-5000 /month  26 Jun 20  Part time allowed
#
#                                                  skills no_of_openings  \
# 2201                              Blogging  Copywriting              1
# 4425                       English Proficiency  Written              3
# 1883                                           MS Excel              2
# 6966  PHP  HTML  CSS  Adobe Dreamweaver  Search Engi...              2
# 3212                                               None             10
# 5130                                               None              2
# 6934                                               None            100
# 935   PHP  HTML  CSS  Adobe Dreamweaver  Search Engi...              2
# 3159                                               None              2
# 1165  MS Office  Adobe Photoshop  Magento  English P...              4
#
#       months_duration
# 2201                6
# 4425                3
# 1883                1
# 6966                1
# 3212                4
# 5130                2
# 6934                2
# 935                 1
# 3159                3
# 1165                3

# %%
df3.stipend[933].split('/')[1].split()[-1].strip()
# Out:
# 'Incentives'

# %%
# extracting the salary and incentives
money_month = []
incentives = []
for i in df3.stipend:
    #print(i.split('/'))
    #print(len(i.split('/')))
    if(len(i.split('/'))>1):
        money_month.append(i.split('/')[0].strip())
        x = i.split('/')[1].split()[-1].strip()
        if x == 'Incentives' or x == 'incentives':
            incentives.append('Yes')
        else:
            incentives.append('No')
    else:
        incentives.append('No')
        money_month.append(None)

# %%
# adding extarcted ones to the dataframe
df3['stipend_month'] = money_month
df3['incentives'] = incentives

# %%
df3.sample(10)
# Out:
#            source        location  \
# 6875  internshala  work_from_home
# 4185  internshala  work_from_home
# 4772  internshala  work_from_home
# 7318  internshala       bangalore
# 423   internshala  work_from_home
# 7405  internshala       bangalore
# 470   internshala  work_from_home
# 6358  internshala  work_from_home
# 1528  internshala  work_from_home
# 7926  internshala       hyderabad
#
#                                                job_link  \
# 6875  https://internshala.com/internship/detail/grap...
# 4185  https://internshala.com/internship/details/con...
# 4772  https://internshala.com/internship/detail/onli...
# 7318  https://internshala.com/internship/detail/hind...
# 423   https://internshala.com/internship/details/dev...
# 7405  https://internshala.com/internship/detail/prod...
# 470   https://internshala.com/internship/details/net...
# 6358  https://internshala.com/internship/details/bus...
# 1528  https://internshala.com/internship/detail/ui-u...
# 7926  https://internshala.com/internship/detail/cont...
#
#                                job_title  \
# 6875                      Graphic Design
# 4185                 Content Development
# 4772                Online Crowd Funding
# 7318          Hindi Video Making/Editing
# 423                  Development Support
# 7405                    Product Analysis
# 470   Networking & System Administration
# 6358        Business Development (Sales)
# 1528                        UI/UX Design
# 7926                     Content Writing
#
#                                  company_name  \
# 6875                              Sportskeeda
# 4185                              Sportskeeda
# 4772               CRY - Child Rights and You
# 7318                          Cook With Parul
# 423                        Child Rights & You
# 7405  Hevo Technologies India Private Limited
# 470        The Energy And Resources Institute
# 6358                 LBB -  Little Black Book
# 1528                      Kotak Mahindra Bank
# 7926      Styling Impressions Private Limited
#
#                                    description_headings  \
# 6875  [About Sportskeeda,  About the work from home ...
# 4185  [About Sportskeeda,  About the work from home ...
# 4772  [About CRY - Child Rights and You,  About the ...
# 7318  [About Cook With Parul,  About part time job/i...
# 423   [About Child Rights & You,  About the work fro...
# 7405  [About Hevo Technologies India Private Limited...
# 470   [About The Energy And Resources Institute,  Ab...
# 6358  [About LBB -  Little Black Book,  About the wo...
# 1528  [About Kotak Mahindra Bank,  About the work fr...
# 7926  [About Styling Impressions Private Limited,  A...
#
#                                             description   start_date  \
# 6875  About Sportskeeda        \r\n\r\nhttps://www.s...  immediately
# 4185  About Sportskeeda        \r\n\r\nhttps://www.s...  immediately
# 4772  About CRY - Child Rights and You        \r\n\r...  immediately
# 7318  About Cook With Parul        \r\n\r\nhttp://co...  immediately
# 423   About Child Rights & You        \r\n\r\nhttps:...  immediately
# 7405  About Hevo Technologies India Private Limited ...  immediately
# 470   About The Energy And Resources Institute      ...  immediately
# 6358  About LBB -  Little Black Book        \r\n\r\n...  immediately
# 1528  About Kotak Mahindra Bank        \r\n\r\nhttps...  immediately
# 7926  About Styling Impressions Private Limited     ...  immediately
#
#       duration                    stipend  last_date           job_mode  \
# 6875  3 Months         12000-15000 /month  26 Jun 20  Part time allowed
# 4185  3 Months  7000 /month +  Incentives  17 Jun 20  Part time allowed
# 4772   4 Weeks                     Unpaid  23 Jun 20  Part time allowed
# 7318  6 Months          8000-10000 /month  29 Jun 20  Part time allowed
# 423   2 Months                     Unpaid  17 Jun 20  Part time allowed
# 7405  6 Months               20000 /month  29 Jun 20               None
# 470   6 Months                5000 /month  16 Jun 20  Part time allowed
# 6358  3 Months           3500-5000 /month  26 Jun 20  Part time allowed
# 1528  6 Months               15000 /month  25 Jun 20  Part time allowed
# 7926  2 Months                3000 /month  28 Jun 20  Part time allowed
#
#                                                  skills no_of_openings  \
# 6875  Adobe Photoshop  Adobe Illustrator  Video Editing              1
# 4185                       English Proficiency  Written              3
# 4772                                               None             10
# 7318                                               None              3
# 423                                                None            100
# 7405                                               None              5
# 470                                                None              2
# 6358  MS Office  Adobe Photoshop  Magento  English P...              4
# 1528       Adobe Photoshop  Adobe Illustrator  Adobe XD              2
# 7926            MS Office  English Proficiency  Written              1
#
#       months_duration stipend_month incentives
# 6875                3   12000-15000         No
# 4185                3          7000        Yes
# 4772                4          None         No
# 7318                6    8000-10000         No
# 423                 2          None         No
# 7405                6         20000         No
# 470                 6          5000         No
# 6358                3     3500-5000         No
# 1528                6         15000         No
# 7926                2          3000         No

# %%
# storing them to csv file
df3.to_csv('modified.csv',index=False)
